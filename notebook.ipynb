# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Task 1
# For every column in the data:
# - State whether the values match the description given in the table above.
# - State the number of missing values in the column.
# - Describe what you did to make values match the description if they did not match.

# %% [markdown]
# ### Solution
#
# **product_id** - This column had no missing values as the database structure did not allow that thus no changes were made.
#
# **category** - This column contained 7 unique values unlike 6 as specified in the criteria, the extra values were `-` which were replaced with `Unknown`
#
# **animal** - The column had 4 unique values matching the criteria and no missing values. No changes were made to the column
#
# **size** - The column had 3 unique values matching the criteria but there was an incosistency in the case. The column values were all made Proper case for consistency.
#
# **price** - The column had no missing values, 150 non numeric values labeled `unlisted` were replaced with the overall median price which was `28.07`  and the decimals precision was ensured by formatting the column to 2 decimal places.
#
# **sales** - The column had complete values, no changes were made
#
# **rating** - The column had 150 missing values denoted by `NA`, they were all replaced with 0 as required.
#
# **repeat_purchase** - The column had no missing values and it matched the criteria. No changes were made to this column

# %% [markdown]
# ## Task 2
# Create a visualization that shows how many products are repeat purchases. Use the
# visualization to:
# - State which category of the variable repeat purchases has the most observations
# - Explain whether the observations are balanced across categories of the variable repeat purchases

# %% [markdown]
# ## Solution
# ![image_2023-08-13_102053594](image_2023-08-13_102053594.png)
#
# + 60 percent of the purchases are repeat purchases whereas 40 percent are not. This means you could create retention strategies for the non repeat customers.
# + The higher count of Repeat Customers indicates that you have a notable segment of loyal customers who make multiple purchases
# + With a balance ratio of 0.655, the categories are leaning towards balanced.
# + A higher number of repeat customers could indicate a high level of customer satisfaction.

# %% [markdown]
# ## Task 3
# Describe the distribution of all of the sales. Your answer must include a visualization
# that shows the distribution.

# %% [markdown]
# ## Solution
# ![image_2023-08-14_083019881](image_2023-08-14_083019881.png)
#
# + The sales distribution is right skewed, with 7 outlier products that have sales of more than 1900 which is not considered unusual, it means several big sales.
# + Most sales are concentrated around 600 to 1400 with the highest count of sales ranging between 1000 and 1100 with a count of 313.

# %% [markdown]
# ## Task 4
# Describe the relationship between repeat purchases and sales. Your answer must
# include a visualization to demonstrate the relationship

# %% [markdown]
# ## Solution
# To check the relationship between sales and repeat purchases, I got the cumulative sales for each repeat purchase category.
# ![image_2023-08-14_085136497](image_2023-08-14_085136497.png)
#
# + Repeat customers are the highest contributors to the overall sales.
#
# + 41 percent of the sales are not repeat sales.
